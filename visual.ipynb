# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(team_df['xG_per_60'], bins=15, kde=True)
plt.title("Distribution of Team Offensive xG/60")
plt.xlabel("xG per 60 minutes")
plt.ylabel("Number of Teams")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
#       4 sns.histplot(team_df['xG_per_60'], bins=15, kde=True)
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
sns.histplot(team_df['xGA_per_60'], bins=15, kde=True)
plt.title("Distribution of Team Defensive xGA/60")
plt.xlabel("xGA per 60 minutes (lower is better)")
plt.show()
